# %% [markdown]
# # Lab Segmentation 2

# %%
from commonfunctions import *
from skimage.filters import threshold_mean,threshold_otsu
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img = io.imread('cameraman.png')
print(img)
print(img.shape)
show_images([img])
# Out:
# [[156 159 158 ... 151 152 152]
#  [160 154 157 ... 154 155 153]
#  [156 159 158 ... 151 152 152]
#  ...
#  [114 132 123 ... 135 137 114]
#  [121 126 130 ... 133 130 113]
#  [121 126 130 ... 133 130 113]]
# (256, 256)

# %%
def getThreshold(image):
    img = np.copy(image)
#     img *= 255
    img = np.array(img.astype("uint8"))
    print(img)
    m = img.shape[0]
    n = img.shape[1]
#     hist = np.zeros(256)
   
#     for i in range(0,m):
#         for j in range(0,n):
#             hist[img[i][j]] +=1
    hist,bins = np.histogram(img,range(0,257))
    numPixels = np.cumsum(hist)[-1]
#     for i in range(0,len(hist)):
#             numPixels += hist[i]
            
    print("numPixels=",numPixels)
    print("histgram length", len(hist))
    print(" length", len(range(0,257)))
    T_init = 0
    L = list(range(0,len(hist)))
#     for i in range(0,len(hist)):
#         T_init += hist[i]*i
    T_init = np.cumsum(np.multiply(L,hist))[-1]
    T_init = int(T_init//numPixels)
    print("T_init = ",T_init)

    T2 = T_init
    T_init = 0
    count = 0
    while(T2 != T_init):
        T_init = T2;
        lowerRange = np.array(hist[0:T_init])
        upperRange = np.array(hist[T_init:])
        lowerCumaltive= np.cumsum(hist[0:T_init])
        upperCumaltive = np.cumsum(hist[T_init:])
        
        Lupper = list(range(T_init,len(hist)))
#         print(Lupper)
        Tupper = np.sum(np.multiply(Lupper,upperRange))
        

        
        Llower = list(range(0,T_init))
#         print(Llower)
        Tlower = np.sum(np.multiply(Llower,lowerRange))

        
        if(upperCumaltive[-1]!=0):
            Tupper = round(Tupper/upperCumaltive[-1])
        else:
            Tupper = T_init
        if(lowerCumaltive[-1]!=0):    
            Tlower = round(Tlower/lowerCumaltive[-1])
        else:
            Tlower = T_init
        T2 = int((Tupper+Tlower)/2)
        print("upperCumaltive",upperCumaltive[-1])
        print("lowerCumaltive",lowerCumaltive[-1])
        print("Tupper",Tupper)
        print("Tlower",Tlower)
        print("T2",T2)
        print("T_init",T_init)
        count += 1
    print("saturated after:",count,"iterations")
    return T2
            
#         Tupper =  upperRange[0]*T_init
#         upperCumaltive[0] = upperRange[0]
#         for i in range(1,len(upperRange)):
#             Tupper += upperRange[i]*(i+T_init)
#             upperCumaltive[i] += upperRange[i]+upperCumaltive[i-1]
#         Tlower = lowerRange[0]*0
#         lowerCumaltive[0] = lowerRange[0]
#         for i in range(1,len(lowerRange)):
#             Tlower += lowerRange[i]*i
#             lowerCumaltive[i] += lowerRange[i]+lowerCumaltive[i-1]

# %%
# img2 = img*255
# img2 = np.array(img2.astype("uint8"))

T = getThreshold(img)
print("thrshold ",T)
T2 = threshold_otsu(img)
print("bulit in threshold",T2)
# Out:
# [[156 159 158 ... 151 152 152]
#  [160 154 157 ... 154 155 153]
#  [156 159 158 ... 151 152 152]
#  ...
#  [114 132 123 ... 135 137 114]
#  [121 126 130 ... 133 130 113]
#  [121 126 130 ... 133 130 113]]
# numPixels= 65536
# histgram length 256
#  length 257
# T_init =  118
# upperCumaltive 42557
# lowerCumaltive 22979
# Tupper 159
# Tlower 43
# T2 101
# T_init 118
# upperCumaltive 46680
# lowerCumaltive 18856
# Tupper 155
# Tlower 29
# T2 92
# T_init 101
# upperCumaltive 47775
# lowerCumaltive 17761
# Tupper 154
# Tlower 25
# T2 89
# T_init 92
# upperCumaltive 48030
# lowerCumaltive 17506
# Tupper 153
# Tlower 24
# T2 88
# T_init 89
# upperCumaltive 48112
# lowerCumaltive 17424
# Tupper 153
# Tlower 23
# T2 88
# T_init 88
# saturated after: 5 iterations
# thrshold  88
# bulit in threshold 88

# %%
def applyThreshold(image,T):
    img=np.copy(image)    
    img[img <= T] = 0
    img[img > T] = 255
    img = img.astype(np.uint8)
#     m = img.shape[0]
#     n = img.shape[1]
#     for i in range(0,m):
#         for j in range(0,n):
#             if(img[i][j] < T):
#                 img[i][j]=0
#             if(img[i][j] > T):
#                 img[i][j]=255
    
    return img

# %%
show_images([img,applyThreshold(img,T),applyThreshold(img,T2)],["image before thresholding","image after thresholding","bulit in"])
